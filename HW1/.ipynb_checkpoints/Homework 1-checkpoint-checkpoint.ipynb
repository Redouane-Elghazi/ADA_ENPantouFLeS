# %% [markdown]
# # Table of Contents
#  <p><div class="lev1"><a href="#Task-1.-Compiling-Ebola-Data"><span class="toc-item-num">Task 1.&nbsp;&nbsp;</span>Compiling Ebola Data</a></div>
#  <div class="lev1"><a href="#Task-2.-RNA-Sequences"><span class="toc-item-num">Task 2.&nbsp;&nbsp;</span>RNA Sequences</a></div>
#  <div class="lev1"><a href="#Task-3.-Class-War-in-Titanic"><span class="toc-item-num">Task 3.&nbsp;&nbsp;</span>Class War in Titanic</a></div></p>

# %%
DATA_FOLDER = 'Data' # Use the data folder provided in Tutorial 02 - Intro to Pandas.

import os
import pandas as pd
os.getcwd()
# Out:
# 'C:\\Users\\PML\\Documents\\EPFL 2017-2018\\ADA_ENPantouFLeS\\HW1'

# %% [markdown]
# ## Task 1. Compiling Ebola Data
#
# The `DATA_FOLDER/ebola` folder contains summarized reports of Ebola cases from three countries (Guinea, Liberia and Sierra Leone) during the recent outbreak of the disease in West Africa. For each country, there are daily reports that contain various information about the outbreak in several cities in each country.
#
# Use pandas to import these data files into a single `Dataframe`.
# Using this `DataFrame`, calculate for *each country*, the *daily average per month* of *new cases* and *deaths*.
# Make sure you handle all the different expressions for *new cases* and *deaths* that are used in the reports.

# %%
#First, for every country, we create a frame with the information we need
#We format them so that they are consistent
#Then we merge the three frames
#We chose to take the cumulative data as it is the data we could consistently find in every record
#We then take one value per month to get the cumulative number of cases/deaths at this month
#Value that we substract by the previous one to get the number of cases/deaths during this month
#Finally we divide this value by 30 to get the daily average of this month
#We observe unexpected value nonetheless
    
#creation of the subframe for guinea
guiT = []
for file in os.listdir(DATA_FOLDER + "/ebola/guinea_data"):
    if file.endswith(".csv"):
        guiT += [pd.read_csv(DATA_FOLDER + '/ebola/guinea_data/' + file)]
gui = pd.concat(guiT)
gui = gui[["Date", "Description", "Totals"]]

gui_death = gui[gui.Description.isin(["Total deaths (confirmed + probables + suspects)"])]
gui_death = gui_death.reset_index()
gui_death = gui_death[["Date","Totals"]]
gui_death.columns = ["Month","Deaths"]

gui_case = gui[gui.Description.isin(["Cumulative (confirmed + probable + suspects)"])]
gui_case = gui_case.reset_index()
gui_case = gui_case[["Date","Totals"]]
gui_case.columns = ["Month","Case"]

gui = pd.merge(gui_case, gui_death)
gui["Month"] = gui["Month"].map(lambda x:int(x.split("-")[1]))

#creation of the subframe for liberia
libT = []
for file in os.listdir(DATA_FOLDER + "/ebola/liberia_data"):
    if file.endswith(".csv"):
        libT += [pd.read_csv(DATA_FOLDER + '/ebola/liberia_data/' + file)]
lib = pd.concat(libT)
lib = lib[["Date", "Variable", "National"]]
lib.columns = ["Date", "Description", "Totals"]

lib_death = lib[lib.Description.isin(["Total death/s in confirmed, probable, suspected cases","Total death/s in confirmed, \r\n probable, suspected cases"])]
lib_death = lib_death.reset_index()
lib_death = lib_death[["Date","Totals"]]
lib_death.columns = ["Month","Deaths"]

lib_case = lib[lib.Description.isin(["Cumulative confirmed, probable and suspected cases"])]
lib_case = lib_case.reset_index()
lib_case = lib_case[["Date","Totals"]]
lib_case.columns = ["Month","Case"]

lib_case2 = lib[lib.Description.isin(["Total suspected cases","Total probable cases","Total confirmed cases"])]
lib_case2 = lib_case2.reset_index()
lib_case2 = lib_case2[["Date","Totals"]]
lib_case2 = lib_case2.fillna(0)
lib_case2['Totals'] = lib_case2['Totals'].map(lambda x: int(float("".join(str(x).split(',')))))
lib_case2 = lib_case2.groupby("Date").agg(sum)
lib_case2 = lib_case2.reset_index()
lib_case2.columns = ["Month","Case"]

lib_case = pd.concat([lib_case, lib_case2])

lib = pd.merge(lib_case, lib_death)
lib["Month"] = lib["Month"].map(lambda x:int(x.split("/")[0]))


#creation of the subframe for sl
slT = []
for file in os.listdir(DATA_FOLDER + "/ebola/sl_data"):
    if file.endswith(".csv"):
        slT += [pd.read_csv(DATA_FOLDER + '/ebola/sl_data/' + file)]
sl = pd.concat(slT)
sl = sl[["date", "variable", "National"]]
sl.columns = ["Date", "Description", "Totals"]

sl_death = sl[sl.Description.isin(["death_confirmed","death_suspected","death_probable"])]
sl_death = sl_death.reset_index()
sl_death = sl_death[["Date","Totals"]]
sl_death = sl_death.fillna(0)
sl_death['Totals'] = sl_death['Totals'].map(int)
sl_death = sl_death.groupby("Date").agg(sum)

sl_death.columns = ["Deaths"]

sl_case = sl[sl.Description.isin(["cum_confirmed","cum_suspected","cum_probable"])]
sl_case = sl_case.reset_index()
sl_case = sl_case[["Date","Totals"]]
sl_case = sl_case.fillna(0)
sl_case['Totals'] = sl_case['Totals'].map(lambda x: int(float("".join(str(x).split(',')))))
sl_case = sl_case.groupby("Date").agg(sum)
sl_case.columns = ["Case"]

sl = pd.concat([sl_case, sl_death], axis=1)
sl["Month"] = sl.index.map(lambda x:int(x.split("-")[1]))


DF = pd.concat([gui, lib, sl], keys=["gui", "lib", "sl"])
DF = DF.reset_index()
DF = DF[["level_0","Case","Deaths","Month"]]
DF.columns = ["Country","Case","Deaths","Month"]

DF_group = DF.groupby(['Country','Month']).agg(max)
DF_group = DF_group.reset_index()
DF_group.columns = ["Country","Month","Category","Average"]
DF_group["Average"] /= 30

#Transforming cumulative data into sequential
DF_group_bis = DF_group.copy()
DF_group_bis['Month'] += 1
DF_group_bis["Average"] *= -1
DF_group = pd.concat([DF_group, DF_group_bis[~DF_group_bis["Month"].isin(DF_group_bis.groupby(["Country"]).agg(max)["Month"])]])
DF_group.groupby(["Country","Month","Category"]).agg(sum)
# Out:
#                            Average
# Country Month Category
# gui     9     Case       32.466667
#               Deaths     23.800000
#         10    Case        7.500000
#               Deaths      0.833333
# lib     6     Case        3.000000
#               Deaths      1.633333
#         7     Case        7.233333
#               Deaths      3.200000
#         8     Case       42.500000
#               Deaths     24.666667
#         9     Case       74.800000
#               Deaths     39.100000
#         10    Case       89.966667
#               Deaths     22.633333
#         11    Case      255.100000
#               Deaths    139.366667
#         12    Case        4.800000
#               Deaths    -29.700000
# sl      8     Case       39.666667
#               Deaths     14.500000
#         9     Case       41.733333
#               Deaths      5.433333
#         10    Case       72.300000
#               Deaths     27.900000
#         11    Case      236.966667
#               Deaths     62.066667
#         12    Case       38.800000
#               Deaths      7.066667

# %% [markdown]
# ## Task 2. RNA Sequences
#
# In the `DATA_FOLDER/microbiome` subdirectory, there are 9 spreadsheets of microbiome data that was acquired from high-throughput RNA sequencing procedures, along with a 10<sup>th</sup> file that describes the content of each.
#
# Use pandas to import the first 9 spreadsheets into a single `DataFrame`.
# Then, add the metadata information from the 10<sup>th</sup> spreadsheet as columns in the combined `DataFrame`.
# Make sure that the final `DataFrame` has a unique index and all the `NaN` values have been replaced by the tag `unknown`.

# %%
#We merge all DataFrame using differents column for the numerical data contained in each of the 9 spredsheets
#And then add as a string all group and sample they were part of

#Loading metadata
meta_data = pd.read_excel(DATA_FOLDER + "/microbiome/metadata.xls")
meta_data.index = meta_data["BARCODE"]
meta_data = meta_data.fillna('NA')


#Loading data files
data_files = ["/microbiome/MID"+str(i) +  ".xls" for i in range(1,10)]

mid = [pd.read_excel(DATA_FOLDER + file_name,sheetname='Sheet 1', header=None) for file_name in data_files]
for i in range(len(mid)):
    mid[i].columns = ["Microbiome",str(i+1)]

#Combining data files
mid_comb = mid[0]
for i in range(1,len(mid)):
    mid_comb = pd.merge(mid_comb,mid[i],how='outer')

#For each row, we note all group and sample in which they appear in a string
mid_comb['Group'] = ''
mid_comb['Sample'] = ''

mid_comb.loc[(mid_comb['1'].notnull(),'Group')] += meta_data.loc['MID1']['GROUP']
mid_comb.loc[(mid_comb['1'].notnull(),'Sample')] += meta_data.loc['MID1']['SAMPLE']

for i in range(1,len(mid)):
   mid_comb.loc[(mid_comb[str(i+1)].notnull(),'Group')] += " " + meta_data.loc["MID" + str(i+1)]['GROUP']
   mid_comb.loc[(mid_comb[str(i+1)].notnull(),'Sample')] += " " + meta_data.loc["MID" + str(i+1)]['SAMPLE']

#Filling NaN with 'unknown' as required
mid_comb = mid_comb.fillna('unknown')
mid_comb.index = mid_comb["Microbiome"]

#Final DataFrame
mid_comb
# Out:
#                                                                                            Microbiome  \
# Microbiome
# Archaea "Crenarchaeota" Thermoprotei Desulfuroc...  Archaea "Crenarchaeota" Thermoprotei Desulfuro...
# Archaea "Crenarchaeota" Thermoprotei Desulfuroc...  Archaea "Crenarchaeota" Thermoprotei Desulfuro...
# Archaea "Crenarchaeota" Thermoprotei Sulfolobal...  Archaea "Crenarchaeota" Thermoprotei Sulfoloba...
# Archaea "Crenarchaeota" Thermoprotei Thermoprot...  Archaea "Crenarchaeota" Thermoprotei Thermopro...
# Archaea "Euryarchaeota" "Methanomicrobia" Metha...  Archaea "Euryarchaeota" "Methanomicrobia" Meth...
# Archaea "Euryarchaeota" "Methanomicrobia" Metha...  Archaea "Euryarchaeota" "Methanomicrobia" Meth...
# Archaea "Euryarchaeota" "Methanomicrobia" Metha...  Archaea "Euryarchaeota" "Methanomicrobia" Meth...
# Archaea "Euryarchaeota" Archaeoglobi Archaeoglo...  Archaea "Euryarchaeota" Archaeoglobi Archaeogl...
# Archaea "Euryarchaeota" Archaeoglobi Archaeoglo...  Archaea "Euryarchaeota" Archaeoglobi Archaeogl...
# Archaea "Euryarchaeota" Halobacteria Halobacter...  Archaea "Euryarchaeota" Halobacteria Halobacte...
# Archaea "Euryarchaeota" Halobacteria Halobacter...  Archaea "Euryarchaeota" Halobacteria Halobacte...
# Archaea "Euryarchaeota" Halobacteria Halobacter...  Archaea "Euryarchaeota" Halobacteria Halobacte...
# Archaea "Euryarchaeota" Halobacteria Halobacter...  Archaea "Euryarchaeota" Halobacteria Halobacte...
# Archaea "Euryarchaeota" Halobacteria Halobacter...  Archaea "Euryarchaeota" Halobacteria Halobacte...
# Archaea "Euryarchaeota" Methanococci Methanococ...  Archaea "Euryarchaeota" Methanococci Methanoco...
# Archaea "Euryarchaeota" Methanopyri Methanopyra...  Archaea "Euryarchaeota" Methanopyri Methanopyr...
# Archaea "Euryarchaeota" Thermoplasmata Thermopl...  Archaea "Euryarchaeota" Thermoplasmata Thermop...
# Bacteria "Actinobacteria" Actinobacteria Actino...  Bacteria "Actinobacteria" Actinobacteria Actin...
# Bacteria "Actinobacteria" Actinobacteria Actino...  Bacteria "Actinobacteria" Actinobacteria Actin...
# Bacteria "Actinobacteria" Actinobacteria Actino...  Bacteria "Actinobacteria" Actinobacteria Actin...
# Bacteria "Actinobacteria" Actinobacteria Actino...  Bacteria "Actinobacteria" Actinobacteria Actin...
# Bacteria "Actinobacteria" Actinobacteria Actino...  Bacteria "Actinobacteria" Actinobacteria Actin...
# Bacteria "Actinobacteria" Actinobacteria Actino...  Bacteria "Actinobacteria" Actinobacteria Actin...
# Bacteria "Actinobacteria" Actinobacteria Actino...  Bacteria "Actinobacteria" Actinobacteria Actin...
# Bacteria "Actinobacteria" Actinobacteria Actino...  Bacteria "Actinobacteria" Actinobacteria Actin...
# Bacteria "Actinobacteria" Actinobacteria Actino...  Bacteria "Actinobacteria" Actinobacteria Actin...
# Bacteria "Actinobacteria" Actinobacteria Actino...  Bacteria "Actinobacteria" Actinobacteria Actin...
# Bacteria "Actinobacteria" Actinobacteria Actino...  Bacteria "Actinobacteria" Actinobacteria Actin...
# Bacteria "Actinobacteria" Actinobacteria Actino...  Bacteria "Actinobacteria" Actinobacteria Actin...
# Bacteria "Actinobacteria" Actinobacteria Actino...  Bacteria "Actinobacteria" Actinobacteria Actin...
# ...                                                                                               ...
# Bacteria "Proteobacteria" Gammaproteobacteria X...  Bacteria "Proteobacteria" Gammaproteobacteria ...
# Bacteria "Proteobacteria" Gammaproteobacteria X...  Bacteria "Proteobacteria" Gammaproteobacteria ...
# Bacteria "Verrucomicrobia" Opitutae Puniceicocc...  Bacteria "Verrucomicrobia" Opitutae Puniceicoc...
# Bacteria "Verrucomicrobia" Subdivision3   Subdi...  Bacteria "Verrucomicrobia" Subdivision3   Subd...
# Bacteria "Bacteroidetes" Flavobacteria "Flavoba...  Bacteria "Bacteroidetes" Flavobacteria "Flavob...
# Bacteria "Bacteroidetes" Flavobacteria "Flavoba...  Bacteria "Bacteroidetes" Flavobacteria "Flavob...
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  Bacteria "Firmicutes" "Clostridia" Clostridial...
# Bacteria "Actinobacteria" Actinobacteria Actino...  Bacteria "Actinobacteria" Actinobacteria Actin...
# Bacteria "Actinobacteria" Actinobacteria Actino...  Bacteria "Actinobacteria" Actinobacteria Actin...
# Bacteria "Chloroflexi" Anaerolineae Anaerolinea...  Bacteria "Chloroflexi" Anaerolineae Anaeroline...
# Bacteria "Deinococcus-Thermus" Deinococci Therm...  Bacteria "Deinococcus-Thermus" Deinococci Ther...
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  Bacteria "Firmicutes" "Clostridia" Clostridial...
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  Bacteria "Firmicutes" "Clostridia" Clostridial...
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  Bacteria "Firmicutes" "Clostridia" Clostridial...
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  Bacteria "Firmicutes" "Clostridia" Clostridial...
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  Bacteria "Firmicutes" "Clostridia" Clostridial...
# Bacteria "Firmicutes" "Clostridia" Halanaerobia...  Bacteria "Firmicutes" "Clostridia" Halanaerobi...
# Bacteria "Firmicutes" "Clostridia" Halanaerobia...  Bacteria "Firmicutes" "Clostridia" Halanaerobi...
# Bacteria "Lentisphaerae" "Lentisphaeria" Victiv...  Bacteria "Lentisphaerae" "Lentisphaeria" Victi...
# Bacteria "Proteobacteria" Alphaproteobacteria R...  Bacteria "Proteobacteria" Alphaproteobacteria ...
# Bacteria "Proteobacteria" Alphaproteobacteria R...  Bacteria "Proteobacteria" Alphaproteobacteria ...
# Bacteria "Proteobacteria" Betaproteobacteria Bu...  Bacteria "Proteobacteria" Betaproteobacteria B...
# Bacteria "Proteobacteria" Betaproteobacteria Rh...  Bacteria "Proteobacteria" Betaproteobacteria R...
# Bacteria "Proteobacteria" Gammaproteobacteria A...  Bacteria "Proteobacteria" Gammaproteobacteria ...
# Bacteria "Proteobacteria" Gammaproteobacteria C...  Bacteria "Proteobacteria" Gammaproteobacteria ...
# Bacteria "Proteobacteria" Gammaproteobacteria M...  Bacteria "Proteobacteria" Gammaproteobacteria ...
# Bacteria "Proteobacteria" Gammaproteobacteria O...  Bacteria "Proteobacteria" Gammaproteobacteria ...
# Bacteria "Proteobacteria" Gammaproteobacteria P...  Bacteria "Proteobacteria" Gammaproteobacteria ...
# Bacteria "Proteobacteria" Gammaproteobacteria P...  Bacteria "Proteobacteria" Gammaproteobacteria ...
# Bacteria "Tenericutes" Mollicutes Anaeroplasmat...  Bacteria "Tenericutes" Mollicutes Anaeroplasma...
#
#                                                           1        2        3  \
# Microbiome
# Archaea "Crenarchaeota" Thermoprotei Desulfuroc...        7       23       14
# Archaea "Crenarchaeota" Thermoprotei Desulfuroc...        2        2  unknown
# Archaea "Crenarchaeota" Thermoprotei Sulfolobal...        3       10        4
# Archaea "Crenarchaeota" Thermoprotei Thermoprot...        3        9        5
# Archaea "Euryarchaeota" "Methanomicrobia" Metha...        7        9        7
# Archaea "Euryarchaeota" "Methanomicrobia" Metha...        1       12        2
# Archaea "Euryarchaeota" "Methanomicrobia" Metha...        1        2        1
# Archaea "Euryarchaeota" Archaeoglobi Archaeoglo...        1        4  unknown
# Archaea "Euryarchaeota" Archaeoglobi Archaeoglo...        1  unknown  unknown
# Archaea "Euryarchaeota" Halobacteria Halobacter...        1        4        3
# Archaea "Euryarchaeota" Halobacteria Halobacter...        4        3        2
# Archaea "Euryarchaeota" Halobacteria Halobacter...        1        5        2
# Archaea "Euryarchaeota" Halobacteria Halobacter...        2        2        2
# Archaea "Euryarchaeota" Halobacteria Halobacter...        4       26       27
# Archaea "Euryarchaeota" Methanococci Methanococ...        1  unknown  unknown
# Archaea "Euryarchaeota" Methanopyri Methanopyra...       12       47       46
# Archaea "Euryarchaeota" Thermoplasmata Thermopl...        2       10       11
# Bacteria "Actinobacteria" Actinobacteria Actino...        2  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...        1  unknown        3
# Bacteria "Actinobacteria" Actinobacteria Actino...        1  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...        1  unknown        5
# Bacteria "Actinobacteria" Actinobacteria Actino...        2  unknown       20
# Bacteria "Actinobacteria" Actinobacteria Actino...       53  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...        1  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...        2  unknown        8
# Bacteria "Actinobacteria" Actinobacteria Actino...        3  unknown        8
# Bacteria "Actinobacteria" Actinobacteria Actino...        1  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...       99  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...       17  unknown        3
# Bacteria "Actinobacteria" Actinobacteria Actino...        2  unknown  unknown
# ...                                                     ...      ...      ...
# Bacteria "Proteobacteria" Gammaproteobacteria X...  unknown  unknown  unknown
# Bacteria "Proteobacteria" Gammaproteobacteria X...  unknown  unknown  unknown
# Bacteria "Verrucomicrobia" Opitutae Puniceicocc...  unknown  unknown  unknown
# Bacteria "Verrucomicrobia" Subdivision3   Subdi...  unknown  unknown  unknown
# Bacteria "Bacteroidetes" Flavobacteria "Flavoba...  unknown  unknown  unknown
# Bacteria "Bacteroidetes" Flavobacteria "Flavoba...  unknown  unknown  unknown
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  unknown  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown  unknown  unknown
# Bacteria "Chloroflexi" Anaerolineae Anaerolinea...  unknown  unknown  unknown
# Bacteria "Deinococcus-Thermus" Deinococci Therm...  unknown  unknown  unknown
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  unknown  unknown  unknown
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  unknown  unknown  unknown
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  unknown  unknown  unknown
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  unknown  unknown  unknown
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  unknown  unknown  unknown
# Bacteria "Firmicutes" "Clostridia" Halanaerobia...  unknown  unknown  unknown
# Bacteria "Firmicutes" "Clostridia" Halanaerobia...  unknown  unknown  unknown
# Bacteria "Lentisphaerae" "Lentisphaeria" Victiv...  unknown  unknown  unknown
# Bacteria "Proteobacteria" Alphaproteobacteria R...  unknown  unknown  unknown
# Bacteria "Proteobacteria" Alphaproteobacteria R...  unknown  unknown  unknown
# Bacteria "Proteobacteria" Betaproteobacteria Bu...  unknown  unknown  unknown
# Bacteria "Proteobacteria" Betaproteobacteria Rh...  unknown  unknown  unknown
# Bacteria "Proteobacteria" Gammaproteobacteria A...  unknown  unknown  unknown
# Bacteria "Proteobacteria" Gammaproteobacteria C...  unknown  unknown  unknown
# Bacteria "Proteobacteria" Gammaproteobacteria M...  unknown  unknown  unknown
# Bacteria "Proteobacteria" Gammaproteobacteria O...  unknown  unknown  unknown
# Bacteria "Proteobacteria" Gammaproteobacteria P...  unknown  unknown  unknown
# Bacteria "Proteobacteria" Gammaproteobacteria P...  unknown  unknown  unknown
# Bacteria "Tenericutes" Mollicutes Anaeroplasmat...  unknown  unknown  unknown
#
#                                                           4        5        6  \
# Microbiome
# Archaea "Crenarchaeota" Thermoprotei Desulfuroc...        2       28        7
# Archaea "Crenarchaeota" Thermoprotei Desulfuroc...  unknown        3        2
# Archaea "Crenarchaeota" Thermoprotei Sulfolobal...  unknown       14        5
# Archaea "Crenarchaeota" Thermoprotei Thermoprot...  unknown       10        4
# Archaea "Euryarchaeota" "Methanomicrobia" Metha...        1       17       12
# Archaea "Euryarchaeota" "Methanomicrobia" Metha...  unknown       11        1
# Archaea "Euryarchaeota" "Methanomicrobia" Metha...  unknown        3        1
# Archaea "Euryarchaeota" Archaeoglobi Archaeoglo...        1        8        4
# Archaea "Euryarchaeota" Archaeoglobi Archaeoglo...  unknown        1  unknown
# Archaea "Euryarchaeota" Halobacteria Halobacter...  unknown        7        4
# Archaea "Euryarchaeota" Halobacteria Halobacter...  unknown        1  unknown
# Archaea "Euryarchaeota" Halobacteria Halobacter...  unknown        1        3
# Archaea "Euryarchaeota" Halobacteria Halobacter...  unknown        1        3
# Archaea "Euryarchaeota" Halobacteria Halobacter...  unknown       36  unknown
# Archaea "Euryarchaeota" Methanococci Methanococ...  unknown  unknown  unknown
# Archaea "Euryarchaeota" Methanopyri Methanopyra...       10       72       23
# Archaea "Euryarchaeota" Thermoplasmata Thermopl...        1       15       11
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown        6  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown        2  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown        3  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown       46  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown        2  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown        2  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown       18  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown        5  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown  unknown  unknown
# ...                                                     ...      ...      ...
# Bacteria "Proteobacteria" Gammaproteobacteria X...  unknown  unknown  unknown
# Bacteria "Proteobacteria" Gammaproteobacteria X...  unknown  unknown  unknown
# Bacteria "Verrucomicrobia" Opitutae Puniceicocc...  unknown  unknown  unknown
# Bacteria "Verrucomicrobia" Subdivision3   Subdi...  unknown  unknown  unknown
# Bacteria "Bacteroidetes" Flavobacteria "Flavoba...  unknown  unknown  unknown
# Bacteria "Bacteroidetes" Flavobacteria "Flavoba...  unknown  unknown  unknown
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  unknown  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown  unknown  unknown
# Bacteria "Chloroflexi" Anaerolineae Anaerolinea...  unknown  unknown  unknown
# Bacteria "Deinococcus-Thermus" Deinococci Therm...  unknown  unknown  unknown
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  unknown  unknown  unknown
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  unknown  unknown  unknown
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  unknown  unknown  unknown
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  unknown  unknown  unknown
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  unknown  unknown  unknown
# Bacteria "Firmicutes" "Clostridia" Halanaerobia...  unknown  unknown  unknown
# Bacteria "Firmicutes" "Clostridia" Halanaerobia...  unknown  unknown  unknown
# Bacteria "Lentisphaerae" "Lentisphaeria" Victiv...  unknown  unknown  unknown
# Bacteria "Proteobacteria" Alphaproteobacteria R...  unknown  unknown  unknown
# Bacteria "Proteobacteria" Alphaproteobacteria R...  unknown  unknown  unknown
# Bacteria "Proteobacteria" Betaproteobacteria Bu...  unknown  unknown  unknown
# Bacteria "Proteobacteria" Betaproteobacteria Rh...  unknown  unknown  unknown
# Bacteria "Proteobacteria" Gammaproteobacteria A...  unknown  unknown  unknown
# Bacteria "Proteobacteria" Gammaproteobacteria C...  unknown  unknown  unknown
# Bacteria "Proteobacteria" Gammaproteobacteria M...  unknown  unknown  unknown
# Bacteria "Proteobacteria" Gammaproteobacteria O...  unknown  unknown  unknown
# Bacteria "Proteobacteria" Gammaproteobacteria P...  unknown  unknown  unknown
# Bacteria "Proteobacteria" Gammaproteobacteria P...  unknown  unknown  unknown
# Bacteria "Tenericutes" Mollicutes Anaeroplasmat...  unknown  unknown  unknown
#
#                                                           7        8        9  \
# Microbiome
# Archaea "Crenarchaeota" Thermoprotei Desulfuroc...        8  unknown       16
# Archaea "Crenarchaeota" Thermoprotei Desulfuroc...        1  unknown  unknown
# Archaea "Crenarchaeota" Thermoprotei Sulfolobal...        5        1        6
# Archaea "Crenarchaeota" Thermoprotei Thermoprot...        5  unknown        5
# Archaea "Euryarchaeota" "Methanomicrobia" Metha...       18  unknown       14
# Archaea "Euryarchaeota" "Methanomicrobia" Metha...        2  unknown        6
# Archaea "Euryarchaeota" "Methanomicrobia" Metha...        2  unknown        3
# Archaea "Euryarchaeota" Archaeoglobi Archaeoglo...        9  unknown        3
# Archaea "Euryarchaeota" Archaeoglobi Archaeoglo...        2  unknown        3
# Archaea "Euryarchaeota" Halobacteria Halobacter...        3  unknown        4
# Archaea "Euryarchaeota" Halobacteria Halobacter...  unknown  unknown        1
# Archaea "Euryarchaeota" Halobacteria Halobacter...        2  unknown        2
# Archaea "Euryarchaeota" Halobacteria Halobacter...        6  unknown        4
# Archaea "Euryarchaeota" Halobacteria Halobacter...        4  unknown        2
# Archaea "Euryarchaeota" Methanococci Methanococ...        1  unknown  unknown
# Archaea "Euryarchaeota" Methanopyri Methanopyra...       59        9       50
# Archaea "Euryarchaeota" Thermoplasmata Thermopl...       10  unknown       16
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...        3  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...        1  unknown        1
# Bacteria "Actinobacteria" Actinobacteria Actino...        1  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...       56  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...       55  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...        5  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...        2  unknown  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown  unknown  unknown
# ...                                                     ...      ...      ...
# Bacteria "Proteobacteria" Gammaproteobacteria X...      133  unknown  unknown
# Bacteria "Proteobacteria" Gammaproteobacteria X...        1  unknown  unknown
# Bacteria "Verrucomicrobia" Opitutae Puniceicocc...        2  unknown  unknown
# Bacteria "Verrucomicrobia" Subdivision3   Subdi...        4  unknown  unknown
# Bacteria "Bacteroidetes" Flavobacteria "Flavoba...  unknown        1  unknown
# Bacteria "Bacteroidetes" Flavobacteria "Flavoba...  unknown        1  unknown
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  unknown        3  unknown
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown  unknown        3
# Bacteria "Actinobacteria" Actinobacteria Actino...  unknown  unknown        1
# Bacteria "Chloroflexi" Anaerolineae Anaerolinea...  unknown  unknown        2
# Bacteria "Deinococcus-Thermus" Deinococci Therm...  unknown  unknown        1
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  unknown  unknown        1
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  unknown  unknown        1
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  unknown  unknown        2
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  unknown  unknown        1
# Bacteria "Firmicutes" "Clostridia" Clostridiale...  unknown  unknown        1
# Bacteria "Firmicutes" "Clostridia" Halanaerobia...  unknown  unknown        1
# Bacteria "Firmicutes" "Clostridia" Halanaerobia...  unknown  unknown        1
# Bacteria "Lentisphaerae" "Lentisphaeria" Victiv...  unknown  unknown        1
# Bacteria "Proteobacteria" Alphaproteobacteria R...  unknown  unknown        1
# Bacteria "Proteobacteria" Alphaproteobacteria R...  unknown  unknown        1
# Bacteria "Proteobacteria" Betaproteobacteria Bu...  unknown  unknown        1
# Bacteria "Proteobacteria" Betaproteobacteria Rh...  unknown  unknown        4
# Bacteria "Proteobacteria" Gammaproteobacteria A...  unknown  unknown      180
# Bacteria "Proteobacteria" Gammaproteobacteria C...  unknown  unknown        1
# Bacteria "Proteobacteria" Gammaproteobacteria M...  unknown  unknown        1
# Bacteria "Proteobacteria" Gammaproteobacteria O...  unknown  unknown        1
# Bacteria "Proteobacteria" Gammaproteobacteria P...  unknown  unknown        1
# Bacteria "Proteobacteria" Gammaproteobacteria P...  unknown  unknown       12
# Bacteria "Tenericutes" Mollicutes Anaeroplasmat...  unknown  unknown        1
#
#                                                                                                 Group  \
# Microbiome
# Archaea "Crenarchaeota" Thermoprotei Desulfuroc...  EXTRACTION CONTROL NEC 1 Control 1 NEC 2 Contr...
# Archaea "Crenarchaeota" Thermoprotei Desulfuroc...  EXTRACTION CONTROL NEC 1 Control 2 NEC 1 Contr...
# Archaea "Crenarchaeota" Thermoprotei Sulfolobal...  EXTRACTION CONTROL NEC 1 Control 1 Control 2 N...
# Archaea "Crenarchaeota" Thermoprotei Thermoprot...  EXTRACTION CONTROL NEC 1 Control 1 Control 2 N...
# Archaea "Euryarchaeota" "Methanomicrobia" Metha...  EXTRACTION CONTROL NEC 1 Control 1 NEC 2 Contr...
# Archaea "Euryarchaeota" "Methanomicrobia" Metha...  EXTRACTION CONTROL NEC 1 Control 1 Control 2 N...
# Archaea "Euryarchaeota" "Methanomicrobia" Metha...  EXTRACTION CONTROL NEC 1 Control 1 Control 2 N...
# Archaea "Euryarchaeota" Archaeoglobi Archaeoglo...  EXTRACTION CONTROL NEC 1 NEC 2 Control 2 NEC 1...
# Archaea "Euryarchaeota" Archaeoglobi Archaeoglo...   EXTRACTION CONTROL Control 2 Control 1 Control 2
# Archaea "Euryarchaeota" Halobacteria Halobacter...  EXTRACTION CONTROL NEC 1 Control 1 Control 2 N...
# Archaea "Euryarchaeota" Halobacteria Halobacter...  EXTRACTION CONTROL NEC 1 Control 1 Control 2 C...
# Archaea "Euryarchaeota" Halobacteria Halobacter...  EXTRACTION CONTROL NEC 1 Control 1 Control 2 N...
# Archaea "Euryarchaeota" Halobacteria Halobacter...  EXTRACTION CONTROL NEC 1 Control 1 Control 2 N...
# Archaea "Euryarchaeota" Halobacteria Halobacter...  EXTRACTION CONTROL NEC 1 Control 1 Control 2 C...
# Archaea "Euryarchaeota" Methanococci Methanococ...                       EXTRACTION CONTROL Control 1
# Archaea "Euryarchaeota" Methanopyri Methanopyra...  EXTRACTION CONTROL NEC 1 Control 1 NEC 2 Contr...
# Archaea "Euryarchaeota" Thermoplasmata Thermopl...  EXTRACTION CONTROL NEC 1 Control 1 NEC 2 Contr...
# Bacteria "Actinobacteria" Actinobacteria Actino...                                 EXTRACTION CONTROL
# Bacteria "Actinobacteria" Actinobacteria Actino...   EXTRACTION CONTROL Control 1 Control 2 Control 1
# Bacteria "Actinobacteria" Actinobacteria Actino...   EXTRACTION CONTROL Control 2 Control 1 Control 2
# Bacteria "Actinobacteria" Actinobacteria Actino...   EXTRACTION CONTROL Control 1 Control 2 Control 1
# Bacteria "Actinobacteria" Actinobacteria Actino...   EXTRACTION CONTROL Control 1 Control 2 Control 1
# Bacteria "Actinobacteria" Actinobacteria Actino...                                 EXTRACTION CONTROL
# Bacteria "Actinobacteria" Actinobacteria Actino...                       EXTRACTION CONTROL Control 2
# Bacteria "Actinobacteria" Actinobacteria Actino...   EXTRACTION CONTROL Control 1 Control 2 Control 1
# Bacteria "Actinobacteria" Actinobacteria Actino...   EXTRACTION CONTROL Control 1 Control 2 Control 1
# Bacteria "Actinobacteria" Actinobacteria Actino...                                 EXTRACTION CONTROL
# Bacteria "Actinobacteria" Actinobacteria Actino...                                 EXTRACTION CONTROL
# Bacteria "Actinobacteria" Actinobacteria Actino...   EXTRACTION CONTROL Control 1 Control 2 Control 1
# Bacteria "Actinobacteria" Actinobacteria Actino...                                 EXTRACTION CONTROL
# ...                                                                                               ...
# Bacteria "Proteobacteria" Gammaproteobacteria X...                                          Control 1
# Bacteria "Proteobacteria" Gammaproteobacteria X...                                          Control 1
# Bacteria "Verrucomicrobia" Opitutae Puniceicocc...                                          Control 1
# Bacteria "Verrucomicrobia" Subdivision3   Subdi...                                          Control 1
# Bacteria "Bacteroidetes" Flavobacteria "Flavoba...                                              NEC 2
# Bacteria "Bacteroidetes" Flavobacteria "Flavoba...                                              NEC 2
# Bacteria "Firmicutes" "Clostridia" Clostridiale...                                              NEC 2
# Bacteria "Actinobacteria" Actinobacteria Actino...                                          Control 2
# Bacteria "Actinobacteria" Actinobacteria Actino...                                          Control 2
# Bacteria "Chloroflexi" Anaerolineae Anaerolinea...                                          Control 2
# Bacteria "Deinococcus-Thermus" Deinococci Therm...                                          Control 2
# Bacteria "Firmicutes" "Clostridia" Clostridiale...                                          Control 2
# Bacteria "Firmicutes" "Clostridia" Clostridiale...                                          Control 2
# Bacteria "Firmicutes" "Clostridia" Clostridiale...                                          Control 2
# Bacteria "Firmicutes" "Clostridia" Clostridiale...                                          Control 2
# Bacteria "Firmicutes" "Clostridia" Clostridiale...                                          Control 2
# Bacteria "Firmicutes" "Clostridia" Halanaerobia...                                          Control 2
# Bacteria "Firmicutes" "Clostridia" Halanaerobia...                                          Control 2
# Bacteria "Lentisphaerae" "Lentisphaeria" Victiv...                                          Control 2
# Bacteria "Proteobacteria" Alphaproteobacteria R...                                          Control 2
# Bacteria "Proteobacteria" Alphaproteobacteria R...                                          Control 2
# Bacteria "Proteobacteria" Betaproteobacteria Bu...                                          Control 2
# Bacteria "Proteobacteria" Betaproteobacteria Rh...                                          Control 2
# Bacteria "Proteobacteria" Gammaproteobacteria A...                                          Control 2
# Bacteria "Proteobacteria" Gammaproteobacteria C...                                          Control 2
# Bacteria "Proteobacteria" Gammaproteobacteria M...                                          Control 2
# Bacteria "Proteobacteria" Gammaproteobacteria O...                                          Control 2
# Bacteria "Proteobacteria" Gammaproteobacteria P...                                          Control 2
# Bacteria "Proteobacteria" Gammaproteobacteria P...                                          Control 2
# Bacteria "Tenericutes" Mollicutes Anaeroplasmat...                                          Control 2
#
#                                                                                                Sample
# Microbiome
# Archaea "Crenarchaeota" Thermoprotei Desulfuroc...   NA tissue tissue tissue tissue stool stool stool
# Archaea "Crenarchaeota" Thermoprotei Desulfuroc...                       NA tissue tissue stool stool
# Archaea "Crenarchaeota" Thermoprotei Sulfolobal...    NA tissue tissue tissue stool stool stool stool
# Archaea "Crenarchaeota" Thermoprotei Thermoprot...          NA tissue tissue tissue stool stool stool
# Archaea "Euryarchaeota" "Methanomicrobia" Metha...   NA tissue tissue tissue tissue stool stool stool
# Archaea "Euryarchaeota" "Methanomicrobia" Metha...          NA tissue tissue tissue stool stool stool
# Archaea "Euryarchaeota" "Methanomicrobia" Metha...          NA tissue tissue tissue stool stool stool
# Archaea "Euryarchaeota" Archaeoglobi Archaeoglo...          NA tissue tissue tissue stool stool stool
# Archaea "Euryarchaeota" Archaeoglobi Archaeoglo...                              NA tissue stool stool
# Archaea "Euryarchaeota" Halobacteria Halobacter...          NA tissue tissue tissue stool stool stool
# Archaea "Euryarchaeota" Halobacteria Halobacter...                      NA tissue tissue tissue stool
# Archaea "Euryarchaeota" Halobacteria Halobacter...          NA tissue tissue tissue stool stool stool
# Archaea "Euryarchaeota" Halobacteria Halobacter...          NA tissue tissue tissue stool stool stool
# Archaea "Euryarchaeota" Halobacteria Halobacter...                NA tissue tissue tissue stool stool
# Archaea "Euryarchaeota" Methanococci Methanococ...                                           NA stool
# Archaea "Euryarchaeota" Methanopyri Methanopyra...  NA tissue tissue tissue tissue stool stool sto...
# Archaea "Euryarchaeota" Thermoplasmata Thermopl...   NA tissue tissue tissue tissue stool stool stool
# Bacteria "Actinobacteria" Actinobacteria Actino...                                                 NA
# Bacteria "Actinobacteria" Actinobacteria Actino...                             NA tissue tissue stool
# Bacteria "Actinobacteria" Actinobacteria Actino...                              NA tissue stool stool
# Bacteria "Actinobacteria" Actinobacteria Actino...                             NA tissue tissue stool
# Bacteria "Actinobacteria" Actinobacteria Actino...                             NA tissue tissue stool
# Bacteria "Actinobacteria" Actinobacteria Actino...                                                 NA
# Bacteria "Actinobacteria" Actinobacteria Actino...                                          NA tissue
# Bacteria "Actinobacteria" Actinobacteria Actino...                             NA tissue tissue stool
# Bacteria "Actinobacteria" Actinobacteria Actino...                             NA tissue tissue stool
# Bacteria "Actinobacteria" Actinobacteria Actino...                                                 NA
# Bacteria "Actinobacteria" Actinobacteria Actino...                                                 NA
# Bacteria "Actinobacteria" Actinobacteria Actino...                             NA tissue tissue stool
# Bacteria "Actinobacteria" Actinobacteria Actino...                                                 NA
# ...                                                                                               ...
# Bacteria "Proteobacteria" Gammaproteobacteria X...                                              stool
# Bacteria "Proteobacteria" Gammaproteobacteria X...                                              stool
# Bacteria "Verrucomicrobia" Opitutae Puniceicocc...                                              stool
# Bacteria "Verrucomicrobia" Subdivision3   Subdi...                                              stool
# Bacteria "Bacteroidetes" Flavobacteria "Flavoba...                                              stool
# Bacteria "Bacteroidetes" Flavobacteria "Flavoba...                                              stool
# Bacteria "Firmicutes" "Clostridia" Clostridiale...                                              stool
# Bacteria "Actinobacteria" Actinobacteria Actino...                                              stool
# Bacteria "Actinobacteria" Actinobacteria Actino...                                              stool
# Bacteria "Chloroflexi" Anaerolineae Anaerolinea...                                              stool
# Bacteria "Deinococcus-Thermus" Deinococci Therm...                                              stool
# Bacteria "Firmicutes" "Clostridia" Clostridiale...                                              stool
# Bacteria "Firmicutes" "Clostridia" Clostridiale...                                              stool
# Bacteria "Firmicutes" "Clostridia" Clostridiale...                                              stool
# Bacteria "Firmicutes" "Clostridia" Clostridiale...                                              stool
# Bacteria "Firmicutes" "Clostridia" Clostridiale...                                              stool
# Bacteria "Firmicutes" "Clostridia" Halanaerobia...                                              stool
# Bacteria "Firmicutes" "Clostridia" Halanaerobia...                                              stool
# Bacteria "Lentisphaerae" "Lentisphaeria" Victiv...                                              stool
# Bacteria "Proteobacteria" Alphaproteobacteria R...                                              stool
# Bacteria "Proteobacteria" Alphaproteobacteria R...                                              stool
# Bacteria "Proteobacteria" Betaproteobacteria Bu...                                              stool
# Bacteria "Proteobacteria" Betaproteobacteria Rh...                                              stool
# Bacteria "Proteobacteria" Gammaproteobacteria A...                                              stool
# Bacteria "Proteobacteria" Gammaproteobacteria C...                                              stool
# Bacteria "Proteobacteria" Gammaproteobacteria M...                                              stool
# Bacteria "Proteobacteria" Gammaproteobacteria O...                                              stool
# Bacteria "Proteobacteria" Gammaproteobacteria P...                                              stool
# Bacteria "Proteobacteria" Gammaproteobacteria P...                                              stool
# Bacteria "Tenericutes" Mollicutes Anaeroplasmat...                                              stool
#
# [775 rows x 12 columns]

# %% [markdown]
# ## Task 3. Class War in Titanic
#
# Use pandas to import the data file `Data/titanic.xls`. It contains data on all the passengers that travelled on the Titanic.

# %%
from IPython.core.display import HTML
HTML(filename=DATA_FOLDER+'/titanic.html')


import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
t_db = pd.read_excel(DATA_FOLDER+'/titanic.xls')

# %% [markdown]
# For each of the following questions state clearly your assumptions and discuss your findings:
# 1. Describe the *type* and the *value range* of each attribute. Indicate and transform the attributes that can be `Categorical`.
# 2. Plot histograms for the *travel class*, *embarkation port*, *sex* and *age* attributes. For the latter one, use *discrete decade intervals*.
# 3. Calculate the proportion of passengers by *cabin floor*. Present your results in a *pie chart*.
# 4. For each *travel class*, calculate the proportion of the passengers that survived. Present your results in *pie charts*.
# 5. Calculate the proportion of the passengers that survived by *travel class* and *sex*. Present your results in *a single histogram*.
# 6. Create 2 equally populated *age categories* and calculate survival proportions by *age category*, *travel class* and *sex*. Present your results in a `DataFrame` with unique index.

# %% [markdown]
# 1-
# We use dtypes for the types, max-min for the range (only on int and float types).
#
# Categorical vairables are the class, the survival, the sex, the embarcation place, and the boat number.
#
# We keep survival not categorical because it is easier to get survival rates with 0s and 1s.

# %%
##1

# Get the types for columns
types=t_db.dtypes.rename('Type')

# Get the value range (max - min) for float/int types columns
value_range=t_db.apply(lambda x: str(x.max()-x.min()) if (x.dtype=='int64' or x.dtype=='float64') else np.nan, reduce=False).rename('Value range')

#The categorical attributes are pclass, survived, sex, embarked and boat
categ=t_db.apply(lambda x: 'Yes' if (x.name in ['pclass','survived','sex','embarked','boat']) else 'No').rename('Categorical?')

# Change the categories
t_db['pclass'] = t_db.pclass.astype('category')

#It is more practical to keep survived numerical
#t_db['survived'] = t_db.survived.astype('category')
t_db['sex'] = t_db.sex.astype('category')
t_db['embarked'] = t_db.embarked.astype('category')
t_db['boat'] = t_db.boat.astype('category')

pd.concat([types,value_range,categ], axis=1)
# Out:
#               Type Value range Categorical?
# pclass       int64           2          Yes
# survived     int64           1          Yes
# name        object         NaN           No
# sex         object         NaN          Yes
# age        float64     79.8333           No
# sibsp        int64           8           No
# parch        int64           9           No
# ticket      object         NaN           No
# fare       float64    512.3292           No
# cabin       object         NaN           No
# embarked    object         NaN          Yes
# boat        object         NaN          Yes
# body       float64       327.0           No
# home.dest   object         NaN           No

# %% [markdown]
# 2-
# We use value_counts to get the number of elements for each category. We keep them ordered with sort_index.
#
# For the embarcation port, we count NaN as 'Others'.
#
# For the age repartition, we set our bins to be in intervals of size 10.
#
# The plots are supposed to be lovely coloured, but we had some issues with the colors depending on the laptop we worked on (sometimes only 1 color appears).

# %%
## 2

# Travel class
t_db['pclass'].value_counts().sort_index().plot(kind="bar", title="Passenger class", color=['gold','lawngreen','steelblue'])
plt.show()

# Embarcation port
t_db['embarked'].replace(np.nan, 'Other', regex=True).value_counts().plot(kind="bar", title="Embarcation port", color=['orangered','cyan','yellow','grey'])
plt.show()

# Sex
t_db['sex'].value_counts().sort_index().plot(kind="bar", title="Sex repartition", color=['salmon','steelblue'])
plt.show()

# Age
t_db['age'].hist(bins=[10*i for i in range(int(float(t_db.age.max())//10)+1)], color='midnightblue')
plt.title("Age repartition")
plt.show()

# %% [markdown]
# 3-
# For this question, we supposed that a floor= A,B,C,D,...
#
# We get the floor by looking at the first letter in 'cabin'.
#
# The data is not really relevant because there are many 'NaN'.

# %%
## 3-

# Create the attribute cabin floor
t_db['floor']=t_db.cabin.apply( lambda x : str(x)[0] if (str(x)[0] in ('A','B','C','D','E','F')) else 'Unknown')


# Do the pie chart
fig, ax = plt.subplots()
ax.set(aspect="equal")
t_db['floor'].value_counts().sort_index().plot(kind='pie',y='floor',colors=['lightyellow','gold','orange','salmon','red','sienna','steelblue']) 
plt.title("Floor repartition")
plt.show()

# %% [markdown]
# 4-
# Again, we use value_counts to get info with categorical attributes.
#
# We plot 3 graphs, each filtered by the class (1,2 or 3).

# %%
## 4-

# Get a circular pie chart
fig, ax = plt.subplots()
ax.set(aspect="equal")

t_db[t_db.pclass==1]['survived'].value_counts().sort_index().plot(kind='pie',y='survived',labels=['No','Yes'],colors=['ivory','gold'], autopct='%.1f%%') 
plt.title("First class survival rate")
plt.show()

# Get a circular pie chart
fig, ax = plt.subplots()
ax.set(aspect="equal")
t_db[t_db.pclass==2]['survived'].value_counts().sort_index().plot(kind='pie',y='survived',labels=['No','Yes'],colors=['ivory','lawngreen'], autopct='%.1f%%') 
plt.title("Second class survival rate")
plt.show()

# Get a circular pie chart
fig, ax = plt.subplots()
ax.set(aspect="equal")
t_db[t_db.pclass==3]['survived'].value_counts().sort_index().plot(kind='pie',y='survived',labels=['No','Yes'],colors=['ivory','steelblue'], autopct='%.1f%%') 
plt.title("Third class survival rate")
plt.show()

# %% [markdown]
# 5-
# We group by class and sex, and as an aggregate we use the fact that the mean of 0s and 1s gives a percentage to directly get the data.

# %%
## 5-

t_db.groupby(['pclass','sex']).agg({'survived': lambda x : 100*x.mean()}).plot(kind="bar", title="Survival rate per class per sex", color=['salmon','steelblue'], legend=False)
plt.show()

# %% [markdown]
# 6-
# We create an age_group attribute, it can be 'Young' or 'Old' whether you are the first age category or in the second. To do so, we apply a parsing function to the age column.
#
# The groupby is similar to question 5.
#
# We reset the indices to get only one index.

# %%
## 6-

t_db['age_group']=t_db.age.apply( lambda x :'Young' if (x<t_db.age.mean()) else 'Old')
t_db.groupby(['age_group','pclass','sex']).agg({'survived': lambda x : 100*x.mean()}).reset_index()
# Out:
#    age_group pclass     sex   survived
# 0        Old      1  female  97.029703
# 1        Old      1    male  30.555556
# 2        Old      2  female  86.363636
# 3        Old      2    male   8.695652
# 4        Old      3  female  47.572816
# 5        Old      3    male  11.718750
# 6      Young      1  female  95.348837
# 7      Young      1    male  48.571429
# 8      Young      2  female  90.322581
# 9      Young      2    male  21.518987
# 10     Young      3  female  50.442478
# 11     Young      3    male  18.987342
